# %% [markdown]
# <a href="https://colab.research.google.com/github/lizhieffe/RL_practicing/blob/main/RL_DPO_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rationale for DPO
#
# - RLHF can be unstable to train. E.g. a small Adam optimizer param change can lead to big difference.

# %% [markdown]
# ## Loss Function

# %% [markdown]
# ![Screenshot 2025-01-18 at 6.38.05 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## My Understanding
#
# Based on
# - Paper: https://arxiv.org/pdf/2305.18290
# - Tutorial: https://www.youtube.com/watch?v=hvGa5Mba4c8&t=1157s

# %% [markdown]
# ### Step 1
#
# Let's assume there is a reward fn (like in RLHF) and pair-wise preference training data. The reward model optimization is usually done via the BT-model.

# %% [markdown]
# ![3w3NKqpjWtAQ78q.png](data:image/png;base64,...)

# %% [markdown]
# ### Step 2
#
# Assuming we have the reward model; then the target of the RLHF can be expressed as

# %% [markdown]
# ![Screenshot 2025-01-18 at 6.51.15 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Step 3
#
# The analytical solution to the KL-constrained reward optimization can be written as

# %% [markdown]
# ![4k6TawyuUzHPnaz.png](data:image/png;base64,...)

# %% [markdown]
# ### Step 4
#
# This analytical equation can be re-arrange as

# %% [markdown]
# ![Screenshot 2025-01-18 at 7.06.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Step 5
#
# Substitute Eq.5 to Eq.1, the BT-model can be rewritten as

# %% [markdown]
# ![Screenshot 2025-01-18 at 7.19.14 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### Step 6
#
# Then optimizating the MLE for human preference (Eq.2) directly updates the policy params

# %% [markdown]
# ![Screenshot 2025-01-18 at 7.20.33 PM.png](data:image/png;base64,...)
